# %%
# question on min-max normalisation

import numpy as np
import pandas as pd
l=[]

x=['Paras','ishant','ujjwal','pratyaya','riddhiman']*10

for i in range(1,51):
    l.append(i)



weight=np.random.randint(40,100,50)
height=np.random.randint(163,230,50)
stipend=np.random.randint(2,20,50)*1000

d={'roll number':l,
   'name':x,
   'weight':weight,
   'height':height,
   'stipend':stipend
  }
data=pd.DataFrame(d)
x=int(input("enter the coloumn for normalisation"))

for y in range(0,x):
    x=input("enter the columns to normalise")

    for i in range(0,50):
        m=max(data[x])
        n=min(data[x])

        d1=data[x][i]
        normal=(d1-n)/(m-n)
        data.loc[i,x]=normal
print(data)
# Out:
# enter the coloumn for normalisation 2
# enter the columns to normalise weight
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_10280\491873095.py:36: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.5660377358490566' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   data.loc[i,x]=normal
# enter the columns to normalise height
#     roll number       name    weight    height  stipend
# 0             1      Paras  0.566038  0.015152    14000
# 1             2     ishant  0.469892  0.943228     5000
# 2             3     ujjwal  0.524479  0.978164     7000
# 3             4   pratyaya  0.697396  0.777278    11000
# 4             5  riddhiman  0.664974  0.781645     7000
# 5             6      Paras  0.945964  0.908291    14000
# 6             7     ishant  1.000000  0.899557    17000
# 7             8     ujjwal  0.654167  0.794746    11000
# 8             9   pratyaya  1.000000  0.720506    16000
# 9            10  riddhiman  0.978385  0.746708    12000
# 10           11      Paras  0.654167  0.742341     7000
# 11           12     ishant  0.632552  0.921392    17000
# 12           13     ujjwal  0.978385  0.951962    11000
# 13           14   pratyaya  0.945964  0.842784    15000
# 14           15  riddhiman  0.870312  0.860253    19000
# 15           16      Paras  0.427213  0.991266     3000
# 16           17     ishant  0.621919  0.777278    19000
# 17           18     ujjwal  0.470687  0.886455     7000
# 18           19   pratyaya  0.902779  0.733607    16000
# 19           20  riddhiman  0.546303  0.912658    13000
# 20           21      Paras  0.881175  0.737974    14000
# 21           22     ishant  0.956791  0.790379     5000
# 22           23     ujjwal  0.470687  0.943228    12000
# 23           24   pratyaya  0.891977  0.768544     6000
# 24           25  riddhiman  0.459884  0.720506     9000
# 25           26      Paras  0.578710  0.755442    16000
# 26           27     ishant  0.891977  0.860253    15000
# 27           28     ujjwal  0.686733  0.995633    18000
# 28           29   pratyaya  1.000000  1.000000    12000
# 29           30  riddhiman  0.740745  0.879992     5000
# 30           31      Paras  0.675931  0.786652     5000
# 31           32     ishant  0.546303  0.933329    18000
# 32           33     ujjwal  0.978395  0.822210    15000
# 33           34   pratyaya  1.000000  0.742205     4000
# 34           35  riddhiman  0.913582  1.000000    18000
# 35           36      Paras  0.913582  0.890403    13000
# 36           37     ishant  0.978395  0.963468    16000
# 37           38     ujjwal  0.459884  0.858438    14000
# 38           39   pratyaya  0.805558  0.936069     2000
# 39           40  riddhiman  0.924384  0.908669    14000
# 40           41      Paras  0.762349  0.753408    18000
# 41           42     ishant  0.438280  0.744275     6000
# 42           43     ujjwal  0.902779  0.771674    16000
# 43           44   pratyaya  0.913582  0.776240     3000
# 44           45  riddhiman  0.740745  0.753408    15000
# 45           46      Paras  0.729942  0.972601     8000
# 46           47     ishant  0.546303  0.917803     8000
# 47           48     ujjwal  0.589512  1.000000     7000
# 48           49   pratyaya  0.643524  1.000000     7000
# 49           50  riddhiman  1.000000  1.000000    18000
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_10280\491873095.py:36: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.015151515151515152' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   data.loc[i,x]=normal
